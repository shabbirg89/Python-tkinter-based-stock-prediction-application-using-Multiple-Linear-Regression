# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import statsmodels.api as sm

# %%
df = pd.read_csv("HDFC.csv")

# %%
df.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.5  293.5  293.50
# 1  2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.0  304.0  304.05
# 2  2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.0  295.0  292.80
# 3  2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.0  296.0  296.45
# 4  2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.0  287.1  286.55
#
#      VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  293.50   22744  6.675364e+11     NaN                 NaN          NaN
# 1  303.62  255251  7.749972e+12     NaN                 NaN          NaN
# 2  294.53  269087  7.925368e+12     NaN                 NaN          NaN
# 3  300.14  305916  9.181669e+12     NaN                 NaN          NaN
# 4  288.80  197039  5.690480e+12     NaN                 NaN          NaN

# %%
plt.scatter(df['Turnover'], df['Open'], color='red')
plt.title('Turnover Vs Open', fontsize=14)
plt.xlabel('Turnover', fontsize=14)
plt.ylabel('Open', fontsize=14)
plt.grid(True)
plt.show()

# %%
df.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998577  0.998004  0.997904  0.997563
# Open                  0.998577  1.000000  0.999284  0.999301  0.998872
# High                  0.998004  0.999284  1.000000  0.998841  0.999407
# Low                   0.997904  0.999301  0.998841  1.000000  0.999339
# Last                  0.997563  0.998872  0.999407  0.999339  1.000000
# Close                 0.997606  0.998907  0.999448  0.999380  0.999958
# VWAP                  0.998055  0.999390  0.999640  0.999614  0.999784
# Volume                0.094629  0.094110  0.094817  0.093415  0.094555
# Turnover              0.371900  0.372209  0.373564  0.371819  0.373243
# Trades                0.548953  0.548854  0.560385  0.539309  0.549997
# Deliverable Volume   -0.000281 -0.000952 -0.001061 -0.001419 -0.000967
# %Deliverble          -0.299439 -0.299524 -0.303714 -0.296236 -0.300635
#
#                        Close      VWAP    Volume  Turnover    Trades  \
# Prev Close          0.997606  0.998055  0.094629  0.371900  0.548953
# Open                0.998907  0.999390  0.094110  0.372209  0.548854
# High                0.999448  0.999640  0.094817  0.373564  0.560385
# Low                 0.999380  0.999614  0.093415  0.371819  0.539309
# Last                0.999958  0.999784  0.094555  0.373243  0.549997
# Close               1.000000  0.999823  0.094504  0.373147  0.549415
# VWAP                0.999823  1.000000  0.094269  0.372972  0.550089
# Volume              0.094504  0.094269  1.000000  0.849492  0.378207
# Turnover            0.373147  0.372972  0.849492  1.000000  0.746064
# Trades              0.549415  0.550089  0.378207  0.746064  1.000000
# Deliverable Volume -0.000949 -0.001222  0.974571  0.743841  0.231320
# %Deliverble        -0.300397 -0.300470  0.021901 -0.089904 -0.244716
#
#                     Deliverable Volume  %Deliverble
# Prev Close                   -0.000281    -0.299439
# Open                         -0.000952    -0.299524
# High                         -0.001061    -0.303714
# Low                          -0.001419    -0.296236
# Last                         -0.000967    -0.300635
# Close                        -0.000949    -0.300397
# VWAP                         -0.001222    -0.300470
# Volume                        0.974571     0.021901
# Turnover                      0.743841    -0.089904
# Trades                        0.231320    -0.244716
# Deliverable Volume            1.000000     0.117356
# %Deliverble                   0.117356     1.000000

# %%
X = df[['Open','Close']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['Turnover']

# %%
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  14635731902314.312
# Coefficients:
#  [-1.19727818e+11  3.03951774e+11]

# %%
# prediction with sklearn
Open = 2.75
Close = 5.3
print ('Predicted Turnover: \n', regr.predict([[Open,Close]]))
# Out:
# Predicted Turnover:
#  [1.59174248e+13]
